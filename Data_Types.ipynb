# %%
5.
# Out:
# 5.0

# %%
.45
# Out:
# 0.45

# %%
type(5)
# Out:
# int

# %%
type(5.)
# Out:
# float

# %%
type('Hello')
# Out:
# str

# %%
# Bool represented using True or False
# We can also understand it as 1 or 0
# and Yes or No
type(True)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
# print(type(123))
# type(123)
# Out:
# <class 'int'>

# %%
"""
What does type do ?
type(obj) -> Tells us what is the type of object

What does print do ?
print(obj) -> Prints obj on the screen
"""

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print("\"Lokesh Antil\"")
# Out:
# "Lokesh Antil"

# %%
a = 4
print(a)
# Out:
# 4

# %%
b = 3.4957
print(b)
# Out:
# 3.4957

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
b = 5
print(type(b))
# Out:
# <class 'int'>

# %%
print( a + b )
print( a * b )
print(a+b, a*b)
# Out:
# 9
# 20
# 9 20

# %%
# How do we take input from user

# %%
input()
# Out:
# Hello
# 'Hello'

# %%
name = input()
print('My name is', name)
# Out:
# Lucy
# My name is Lucy

# %%
name = input()
age = input()
# age = '25'
print('Age of', name, 'is', age)
# Out:
# Aarnav
# 25
# Age of Aarnav is 25

# %%
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'str'>

# %%
int_age = int(age)
print(type(int_age))
# Out:
# <class 'int'>

# %%
age = int(input())
print(type(age))
# Out:
# 265
# <class 'int'>

# %%
print('2' + "2")
# '2'+"2" => '22' => print('22') => output 22
# print(str+str) ->
# Out:
# 22

# %%
# You will get a name in input
# Print Hello name

name = input()
print('hello', name)
# Out:
# Aarnav
# hello Aarnav

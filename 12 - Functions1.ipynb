# %% [markdown]
# # Functions 1

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
def make_tea() :
  print("Boil some milk")
  print("Add sugar and tea leaves")
  print("Add some milk")
  print("Heat for a few mins")


def make_coffee() :
  print("Heat some water")
  print("Put coffee & sugar in the cup")
  print("Pour hot water into the cup")

# %%
make_tea()
print()
make_coffee()
print()
make_tea()
print()
make_tea()
print()
make_coffee()
# Out:
# Boil some milk
# Add sugar and tea leaves
# Add some milk
# Heat for a few mins
#
# Heat some water
# Put coffee & sugar in the cup
# Pour hot water into the cup
#
# Boil some milk
# Add sugar and tea leaves
# Add some milk
# Heat for a few mins
#
# Boil some milk
# Add sugar and tea leaves
# Add some milk
# Heat for a few mins
#
# Heat some water
# Put coffee & sugar in the cup
# Pour hot water into the cup

# %%
for i in range(3) :
  make_tea()
# Out:
# Boil some milk
# Add sugar and tea leaves
# Add some milk
# Heat for a few mins
# Boil some milk
# Add sugar and tea leaves
# Add some milk
# Heat for a few mins
# Boil some milk
# Add sugar and tea leaves
# Add some milk
# Heat for a few mins

# %%
def abc() :
  x = 10
  y = 5
  print(x+y)

abc()
# Out:
# 15

# %% [markdown]
# ## Arguments / Parameters

# %%
# Argument / Parameter -> Value sent to a function from the outside
def robot_welcome(name):
  print("Hello", name, "! Nice to meet you 🙂")

# %%
name = input()
robot_welcome(name)
# Out:
# Aarnav
# Hello Aarnav ! Nice to meet you 🙂

# %% [markdown]
# <img src="https://media.giphy.com/media/KSCYjxdjm0yA0/giphy.gif" width="300px" />

# %%
def sheldon_knock(name) :
  print(name,"...", name, "...", name, "...")


sheldon_knock("Raj")
sheldon_knock(123)
# Out:
# Raj ... Raj ... Raj ...
# 123 ... 123 ... 123 ...

# %%
def print_stuff(val1, val2) :
  print("Val1 is", val1)
  print("Val2 is", val2)


print_stuff(123, "Aarnav")
# print_stuff(1, "YOLO", False) -> Error
# print_stuff(23) -> Error

# Aarnav -> Variable
# "Aarnav" -> String

def random_func() :
  pass
# Out:
# Val1 is 123
# Val2 is Aarnav

# %%
# Break - 10:05pm

# %%
# Quiz 1

def voldy(horcrux1, horcrux2, horcrux3, horcrux4):
    print(horcrux3)
    print(horcrux1)
    print(horcrux4)
    print(horcrux2)

voldy("Hufflepuff's Cup", "Harry Potter", "Tom Riddle's Diary", "Ravenclaw's Diadem")
# Out:
# Tom Riddle's Diary
# Hufflepuff's Cup
# Ravenclaw's Diadem
# Harry Potter

# %% [markdown]
# <img src="https://media.giphy.com/media/LLxwPAjfpLak8/giphy.gif" width="300px" />

# %% [markdown]
# ### Write a function which takes one number as argument and prints its square.

# %%
def square(x) :
  print(x**2)

x = int(input())
square(x)
square(5)
square(1.2)
# square("aarnav")
# Out:
# 20
# 400
# 25
# 1.44

# %% [markdown]
# ![download-1.png](data:image/png;base64,...)

# %% [markdown]
# ### Write a function which takes one number as argument and prints its cube

# %%
def cube(x) :
  print(x**3)

cube(5)
cube(1.5)
# Out:
# 125
# 3.375

# %% [markdown]
# ## Return
# <img src="https://media.giphy.com/media/LPemN8PSiCNyXQ1wxs/giphy.gif" width="300px" />

# %%
# f(x) -> y

# f(x) = x**2

# I can do 2 things with the result
# 1. Print it
# 2. Return it

# %%
def add(a, b):
  # print(a+b)
  return a + b


res = add(5, 7)
print("Sqaure of sum is", res**2)
# Out:
# Sqaure of sum is 144

# %%
def square(x) :
  return x**2

def pythagoras(x, y) :
  return square(x)+square(y)

sum = pythagoras(3, 4)
print(sum)
# Out:
# 25

# %%
def multiply(a, b):
    return a * b

# %% [markdown]
# #### Quiz 3
# Functions-add \
# Predict the output
# ```py
# res = add(3, 5)
# print(res)
#
# def add(x, y):
#     return x + y
# ```

# %%
res = add(3, 5)
print(res)

def add(x, y):
    return x + y

# If you want to use a function, you have to define it first.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jn/1bsrct314hv5xmfm7vrcdrzc0000gn/T/ipykernel_2585/716448176.py in <module>
# ----> 1 res = add(3, 5)
#       2 print(res)
#       3
#       4 def add(x, y):
#       5     return x + y
#
# NameError: name 'add' is not defined

# %%
def add(x, y):
    return x + y

res = add(3, 5)
print(res)
# Out:
# 8

# %% [markdown]
# #### Quiz 4
# ```py
# def foo_bar():
#     print('Foo')
#     return 1
#     print('Bar')
#
# res = foo_bar()
# print(res)
# ```

# %%
# return is the end of the function

def foo_bar():
    print('Foo')
    return "BOO"
    print('Bar')

res = foo_bar()
print(res)
# Out:
# Foo
# BOO

# %% [markdown]
# No code after the return statement is executed. Return is the last statement executed in any function.

# %%
def solve() :
  # write your logic here
  pass

if __name__ == "__main__":
  solve()

# %% [markdown]
# ## Important Note:
# In your today's assignments/homework problems, print only and only if the questions asks you to.

# %% [markdown]
# ## Docstrings
# <img src="https://media.giphy.com/media/UyPpKZScnl7na/giphy.gif" width="300px" />

# %%
help(range)
# Out:
# Help on class range in module builtins:
#
# class range(object)
#  |  range(stop) -> range object
#  |  range(start, stop[, step]) -> range object
#  |
#  |  Return an object that produces a sequence of integers from start (inclusive)
#  |  to stop (exclusive) by step.  range(i, j) produces i, i+1, i+2, ..., j-1.
#  |  start defaults to 0, and stop is omitted!  range(4) produces 0, 1, 2, 3.
#  |  These are exactly the valid indices for a list of 4 elements.
#  |  When step is given, it specifies the increment (or decrement).
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
# ...

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of google.colab._kernel.Kernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplentedError if active frontend doesn't support stdin.

# %%
help(add)
# Out:
# Help on function add in module __main__:
#
# add(a, b)

# %%
def add(a, b):
    """
    Returns the sum of two numbers
    """
    return a + b

help(add)
# Out:
# Help on function add in module __main__:
#
# add(a, b)
#     Returns the sum of two numbers

# %% [markdown]
# # Bonus Reading Material
# https://www.scaler.com/topics/python/functions-in-python/

# %%
def func(a,b):
  print(a, "L1")
  return 1
  print(b, "L2")

x = func(1,2)
print(x, "L3")
# Out:
# 1 L1
# 1 L3
